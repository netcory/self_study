# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('food_db.xlsx', '통계용')
df
# Out:
#                       Unnamed: 0      Unnamed: 1  \
# 0      최종 DB 업데이트 일 : 2021-05-14             NaN
# 1                            NaN             NaN
# 2                             NO       SAMPLE_ID
# 3                              1  D000006-94-AVG
# 4                              2  D000007-ZZ-AVG
# ...                          ...             ...
# 59230                      59228  P064127-ZZ-AVG
# 59231                      59229  P064128-ZZ-AVG
# 59232                      59230  P064129-ZZ-AVG
# 59233                      59231  P064130-ZZ-AVG
# 59234                      59232  P064131-ZZ-AVG
#
#                                               Unnamed: 2 Unnamed: 3  \
# 0      ● 이 파일은 통계용으로 사용하기 위한 것으로, 기존 "-"값이 "0"으로 변환된 ...        NaN
# 1                                                    NaN        NaN
# 2                                                   식품코드        DB군
# 3                                                D000006         음식
# ...

# %%
# 불필요한 행 제거
df = df.drop([df.index[0], df.index[1]])

# %%
df.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2             NO       SAMPLE_ID       식품코드        DB군       상용제품
# 3              1  D000006-94-AVG    D000006         음식       품목대표
# 4              2  D000007-ZZ-AVG    D000007         음식       품목대표
# 5              3  D000008-66-AVG    D000008         음식       품목대표
# 6              4  D000009-ZZ-AVG    D000009         음식       품목대표
# ...          ...             ...        ...        ...        ...
# 59230      59228  P064127-ZZ-AVG    P064127       가공식품       상용제품
# 59231      59229  P064128-ZZ-AVG    P064128       가공식품       상용제품
# 59232      59230  P064129-ZZ-AVG    P064129       가공식품       상용제품
# 59233      59231  P064130-ZZ-AVG    P064130       가공식품       상용제품
# 59234      59232  P064131-ZZ-AVG    P064131       가공식품       상용제품
#
#            Unnamed: 5 Unnamed: 6  \
# 2                 식품명         연도
# 3                꿩불고기       2019
# 4                 닭갈비       2019
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 245', 'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248',
#        'Unnamed: 249', 'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252',
#        'Unnamed: 253', 'Unnamed: 254'],
#       dtype='object', length=255)

# %%
a = df.iloc[0]
a_list = list(a)
a_list
# Out:
# ['NO',
#  'SAMPLE_ID',
#  '식품코드',
#  'DB군',
#  '상용제품',
#  '식품명',
#  '연도',
#  '지역 / 제조사',
#  '채취시기',
#  '식품대분류',
#  '식품상세분류',
#  '1회제공량',
#  '내용량_단위',
#  '총내용량(g)',
#  '총내용량(mL)',
#  '에너지(㎉)',
#  '에너지(kj)',
#  '수분(g)',
#  '수분(%)',
#  '단백질(g)',
#  '지방(g)',
#  '지질-가식부 100g당',
#  '탄수화물(g)',
#  '총당류(g)',
#  '자당(g)',
#  '포도당(g)',
#  '과당(g)',
#  '유당(g)',
#  '맥아당(g)',
#  '갈락토오스(g)',
#  '당알콜(g)',
#  '에리스리톨(g)',
#  '총 식이섬유(g)',
#  '총 식이섬유(mg)',
#  '총 식이섬유(%)',
#  '수용성 식이섬유(g)',
#  '불용성 식이섬유(g)',
#  '셀룰로오스(%)',
#  '리그닌(%)',
#  '칼슘(㎎)',
#  '철(㎎)',
#  '철(㎍)',
#  '마그네슘(㎎)',
#  '인(㎎)',
#  '칼륨(g)',
#  '칼륨(㎎)',
#  '나트륨(㎎)',
#  '아연(㎎)',
#  '구리(㎎)',
#  '구리(㎍)',
#  '망간(㎎)',
#  '망간(㎍)',
#  '셀레늄(㎍)',
#  '몰리브덴(㎍)',
#  '요오드(㎍)',
#  '염소(㎎)',
#  '비타민 A(㎍)',
#  '비타민 A(㎍ RE)',
#  '레티놀(㎍)',
#  '베타카로틴(㎍)',
#  '레티놀A효능',
#  '비타민 D(D2+D3)(㎍)',
#  '비타민 D2(㎍)',
#  '비타민 D3(㎍)',
#  '비타민 D1(㎍)',
#  '비타민 E(㎎)',
#  '비타민 E(㎎ α-TE)',
#  '알파 토코페롤(㎎)',
#  '베타 토코페롤(㎎)',
#  '감마 토코페롤(㎎)',
#  '델타 토코페롤(㎎)',
#  '알파 토코트리에놀(㎎)',
# ...

# %%
df.columns = a_list

# %%
df.head
# Out:
# <bound method NDFrame.head of           NO       SAMPLE_ID     식품코드   DB군  상용제품             식품명    연도  \
# 2         NO       SAMPLE_ID     식품코드   DB군  상용제품             식품명    연도
# 3          1  D000006-94-AVG  D000006    음식  품목대표            꿩불고기  2019
# 4          2  D000007-ZZ-AVG  D000007    음식  품목대표             닭갈비  2019
# 5          3  D000008-66-AVG  D000008    음식  품목대표             닭갈비  2019
# 6          4  D000009-ZZ-AVG  D000009    음식  품목대표             닭꼬치  2019
# ...      ...             ...      ...   ...   ...             ...   ...
# 59230  59228  P064127-ZZ-AVG  P064127  가공식품  상용제품          블루베리 쨈  2020
# 59231  59229  P064128-ZZ-AVG  P064128  가공식품  상용제품       오렌지 마말레이드  2020
# 59232  59230  P064129-ZZ-AVG  P064129  가공식품  상용제품            오렌지잼  2020
# 59233  59231  P064130-ZZ-AVG  P064130  가공식품  상용제품  자연은 착즙 100 오렌지  2020
# 59234  59232  P064131-ZZ-AVG  P064131  가공식품  상용제품    해피 할로윈(300g)  2020
#
# ...

# %%
df.columns
# Out:
# Index([       'NO', 'SAMPLE_ID',      '식품코드',       'DB군',      '상용제품',
#              '식품명',        '연도',  '지역 / 제조사',      '채취시기',     '식품대분류',
#        ...
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan],
#       dtype='object', length=255)

# %%
df.head()
# Out:
#    NO       SAMPLE_ID     식품코드  DB군  상용제품   식품명    연도  지역 / 제조사  채취시기  식품대분류  \
# 2  NO       SAMPLE_ID     식품코드  DB군  상용제품   식품명    연도  지역 / 제조사  채취시기  식품대분류
# 3   1  D000006-94-AVG  D000006   음식  품목대표  꿩불고기  2019        충주    평균    구이류
# 4   2  D000007-ZZ-AVG  D000007   음식  품목대표   닭갈비  2019    전국(대표)    평균    구이류
# 5   3  D000008-66-AVG  D000008   음식  품목대표   닭갈비  2019        춘천    평균    구이류
# 6   4  D000009-ZZ-AVG  D000009   음식  품목대표   닭꼬치  2019    전국(대표)    평균    구이류
#
#    ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 5  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 255 columns]

# %%
# nan 칼럼 전부 제거
df = df.dropna(axis=1)
df.head()
# Out:
#   NO       SAMPLE_ID     식품코드 DB군  상용제품   식품명    연도 채취시기 식품대분류 식품상세분류  ...  \
# 3  1  D000006-94-AVG  D000006  음식  품목대표  꿩불고기  2019   평균   구이류   육류구이  ...
# 4  2  D000007-ZZ-AVG  D000007  음식  품목대표   닭갈비  2019   평균   구이류   육류구이  ...
# 5  3  D000008-66-AVG  D000008  음식  품목대표   닭갈비  2019   평균   구이류   육류구이  ...
# 6  4  D000009-ZZ-AVG  D000009  음식  품목대표   닭꼬치  2019   평균   구이류   육류구이  ...
# 7  5  D000010-ZZ-AVG  D000010  음식  품목대표  더덕구이  2019   평균   구이류  채소류구이  ...
#
#   냉산가용성물질(㎎) 총 불포화지방산(g) 식염상당량(g) 회분(g) 폐기율(%) 가식부(%) 산가용성물질(%) 카페인(㎎)  \
# 3          0           0        0     6      0      0         0      0
# 4          0           0        0     7      0      0         0      0
# 5          0           0        0     5      0      0         0      0
# 6          0           0        0     1      0      0         0      0
# 7          0           0        0     3      0      0         0      0
#
#           성분표출처      발행기관
# 3  식약처('16) 제4권  식품의약품안전처
# 4  식약처('16) 제4권  식품의약품안전처
# ...
